# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# %%
df=pd.read_csv('Cleaned_Diabetes.csv',index_col=0)
df
# Out:
#      Pregnancies  Glucose  BloodPressure  SkinThickness  Insulin   BMI  \
# 0              6      148             72             35    125.0  33.6
# 1              1       85             66             29    125.0  26.6
# 2              8      183             64             32    125.0  23.3
# 3              1       89             66             23     94.0  28.1
# 4              0      137             40             35    168.0  43.1
# ..           ...      ...            ...            ...      ...   ...
# 763           10      101             76             48    180.0  32.9
# 764            2      122             70             27    125.0  36.8
# 765            5      121             72             23    112.0  26.2
# 766            1      126             60             32    125.0  30.1
# 767            1       93             70             31    125.0  30.4
#
#      DiabetesPedigreeFunction  Age  Outcome  High_BloodPressure   Wieght  \
# ...

# %%
train_set, test_set = train_test_split(df, test_size=0.2, random_state=777)
# this is how we will need to split our test later
​
#X = df_n.drop('Avg Salary', axis=1)
#y = df_n['Avg Salary'].values
​
#X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=777)
train_set.to_csv('train_set_dia.csv')
test_set.to_csv('test_set.csv')
​
